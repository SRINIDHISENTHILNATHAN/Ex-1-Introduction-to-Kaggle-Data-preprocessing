# %%
import pandas as pd
import io
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Churn_Modelling.csv", index_col="RowNumber")
df
# Out:
#            CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602   Hargrave          619    France  Female   42       2
# 2            15647311       Hill          608     Spain  Female   41       1
# 3            15619304       Onio          502    France  Female   42       8
# 4            15701354       Boni          699    France  Female   39       1
# 5            15737888   Mitchell          850     Spain  Female   43       2
# ...               ...        ...          ...       ...     ...  ...     ...
# 9996         15606229   Obijiaku          771    France    Male   39       5
# 9997         15569892  Johnstone          516    France    Male   35      10
# 9998         15584532        Liu          709    France  Female   36       7
# 9999         15682355  Sabbatini          772   Germany    Male   42       3
# 10000        15628319     Walker          792    France  Female   28       4
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
# ...              ...            ...        ...             ...
# 9996            0.00              2          1               0
# 9997        57369.61              1          1               1
# 9998            0.00              1          0               1
# 9999        75075.31              2          1               0
# 10000      130142.79              1          1               0
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0
# ...                    ...     ...
# 9996              96270.64       0
# 9997             101699.77       0
# 9998              42085.58       1
# 9999              92888.52       1
# 10000             38190.78       0
#
# [10000 rows x 13 columns]

# %%
df.drop(['CustomerId'],axis=1,inplace=True)
df.drop(['Surname'],axis=1,inplace=True)
df.drop('Age',axis=1,inplace=True)
df.drop('Geography',axis=1,inplace=True)
df.drop('Gender',axis=1,inplace=True)
df
# Out:
#            CreditScore  Tenure    Balance  NumOfProducts  HasCrCard  \
# RowNumber
# 1                  619       2       0.00              1          1
# 2                  608       1   83807.86              1          0
# 3                  502       8  159660.80              3          1
# 4                  699       1       0.00              2          0
# 5                  850       2  125510.82              1          1
# ...                ...     ...        ...            ...        ...
# 9996               771       5       0.00              2          1
# 9997               516      10   57369.61              1          1
# 9998               709       7       0.00              1          0
# 9999               772       3   75075.31              2          1
# 10000              792       4  130142.79              1          1
#
#            IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                       1        101348.88       1
# 2                       1        112542.58       0
# 3                       0        113931.57       1
# 4                       0         93826.63       0
# 5                       1         79084.10       0
# ...                   ...              ...     ...
# 9996                    0         96270.64       0
# 9997                    1        101699.77       0
# 9998                    1         42085.58       1
# 9999                    0         92888.52       1
# 10000                   0         38190.78       0
#
# [10000 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.duplicated()
# Out:
# RowNumber
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 9996     False
# 9997     False
# 9998     False
# 9999     False
# 10000    False
# Length: 10000, dtype: bool

# %%
df.describe()
# Out:
#         CreditScore        Tenure        Balance  NumOfProducts    HasCrCard  \
# count  10000.000000  10000.000000   10000.000000   10000.000000  10000.00000
# mean     650.528800      5.012800   76485.889288       1.530200      0.70550
# std       96.653299      2.892174   62397.405202       0.581654      0.45584
# min      350.000000      0.000000       0.000000       1.000000      0.00000
# 25%      584.000000      3.000000       0.000000       1.000000      0.00000
# 50%      652.000000      5.000000   97198.540000       1.000000      1.00000
# 75%      718.000000      7.000000  127644.240000       2.000000      1.00000
# max      850.000000     10.000000  250898.090000       4.000000      1.00000
#
#        IsActiveMember  EstimatedSalary        Exited
# count    10000.000000     10000.000000  10000.000000
# mean         0.515100    100090.239881      0.203700
# std          0.499797     57510.492818      0.402769
# min          0.000000        11.580000      0.000000
# 25%          0.000000     51002.110000      0.000000
# 50%          1.000000    100193.915000      0.000000
# 75%          1.000000    149388.247500      0.000000
# max          1.000000    199992.480000      1.000000

# %%
scaler=StandardScaler()
df1=pd.DataFrame(scaler.fit_transform(df))
df1
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.326221 -1.041760 -1.225848 -0.911583  0.646092  0.970243  0.021886
# 1    -0.440036 -1.387538  0.117350 -0.911583 -1.547768  0.970243  0.216534
# 2    -1.536794  1.032908  1.333053  2.527057  0.646092 -1.030670  0.240687
# 3     0.501521 -1.387538 -1.225848  0.807737 -1.547768 -1.030670 -0.108918
# 4     2.063884 -1.041760  0.785728 -0.911583  0.646092  0.970243 -0.365276
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  1.246488 -0.004426 -1.225848  0.807737  0.646092 -1.030670 -0.066419
# 9996 -1.391939  1.724464 -0.306379 -0.911583  0.646092  0.970243  0.027988
# 9997  0.604988  0.687130 -1.225848 -0.911583 -1.547768  0.970243 -1.008643
# 9998  1.256835 -0.695982 -0.022608  0.807737  0.646092 -1.030670 -0.125231
# 9999  1.463771 -0.350204  0.859965 -0.911583  0.646092 -1.030670 -1.076370
#
#              7
# 0     1.977165
# 1    -0.505775
# 2     1.977165
# 3    -0.505775
# 4    -0.505775
# ...        ...
# 9995 -0.505775
# 9996 -0.505775
# 9997  1.977165
# 9998  1.977165
# 9999 -0.505775
#
# [10000 rows x 8 columns]

# %%
x=df1.iloc[:,:-1].values
x
# Out:
# array([[-0.32622142, -1.04175968, -1.22584767, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-0.44003595, -1.38753759,  0.11735002, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-1.53679418,  1.03290776,  1.33305335, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [ 0.60498839,  0.68712986, -1.22584767, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [ 1.25683526, -0.69598177, -0.02260751, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [ 1.46377078, -0.35020386,  0.85996499, ...,  0.64609167,
#         -1.03067011, -1.07636976]])

# %%
y=df1.iloc[:,-1].values
y
# Out:
# array([ 1.97716468, -0.50577476,  1.97716468, ...,  1.97716468,
#         1.97716468, -0.50577476])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(x_train)
print(len(x_train))
print(x_test)
print(len(x_test))
# Out:
# [[-0.85390698 -1.38753759  0.81423147 ... -1.54776799 -1.03067011
#   -0.94733068]
#  [-0.66766502 -1.04175968 -1.22584767 ...  0.64609167  0.97024255
#   -0.13951004]
#  [-0.7193989  -1.73331549  0.39315525 ... -1.54776799  0.97024255
#   -1.60263795]
#  ...
#  [-0.56419726 -1.04175968 -1.22584767 ...  0.64609167  0.97024255
#   -1.5306294 ]
#  [-1.12292315 -1.04175968  1.57720599 ...  0.64609167  0.97024255
#   -1.35244153]
#  [-0.00547137 -1.38753759  1.22579881 ... -1.54776799  0.97024255
#   -0.29769187]]
# 8000
# [[ 0.69810937  1.03290776 -1.22584767 ...  0.64609167  0.97024255
#   -1.73798593]
#  [-1.4850603  -0.69598177 -0.283128   ...  0.64609167  0.97024255
#    0.66853492]
#  [-2.05413297  0.68712986  1.23693028 ...  0.64609167 -1.03067011
#    0.20480748]
#  ...
#  [ 2.06388377 -0.69598177 -1.22584767 ... -1.54776799  0.97024255
#    1.37843514]
#  [ 1.31891592  0.68712986  0.53014808 ... -1.54776799  0.97024255
#    0.22530181]
#  [ 0.58429484 -1.38753759 -1.22584767 ... -1.54776799  0.97024255
#   -1.63551777]]
# 2000
